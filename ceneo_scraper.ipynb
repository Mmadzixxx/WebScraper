# %% [markdown]
# Import bibliotek

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Pobieranie z serwisu Ceneo.pl opinii o wybranym produkcie

# %% [markdown]
# Potencjalne produkty:
#
# *   7690465
# *   187595793
# *   130492450
# *   102474186
# *   47293506
# *   39562616

# %%
headers = {
    "Cookie": "__RequestVerificationToken=6oMGtEWKP9AKp1e4v0is0S7iLL4x-7K4Nje9r4HBf3gwOGArsi5zJRBaUYC-iZVA9Ek59GFMFnlsMPx1Ld7Lx0w485EsfHF9MIAt2BuK_f41; st2=_gd%3dwww.google.com%2csref%3dhttps%3a%2f%2fwww.google.com%2f%2c_t%3d63908922115%2cencode%3dtrue; __utmf=fedb735cc357b2481130cdd1576de127_Dsgqi6QMc9CtX7buqOpcIw%3D%3D; sv3=1.0_7308ed49-1e16-11f1-8bd0-36b44b77cf78; userCeneo=ID=a180578e-3e3f-4bdf-ae26-aa1c791773b3; ai_user=jyEA3|2026-03-12T13:21:59.654Z; appType=%7B%22Value%22%3A1%7D; cProdCompare_v2=; browserBlStatus=0; ga4_ga=GA1.2.7308ed49-1e16-11f1-8bd0-36b44b77cf78; _gcl_au=1.1.1436311283.1773321722; consentcookie=...; FPID=FPID2.2.JSzKk%2BvCJojLyN18Vf7Z%2BZILSLBBZ%2FqzpSnpNpfW260%3D; FPLC=IqWStrnopHsrs52kalULqfm933VU6PqLtZBPwrpAGF6blxm49JjoKdtO1COQ8BNmg3DteNn5t9UektFlpkSPWoJ2eLZJZlB4%2FKi9eJLLiIeO9lw%3D; _fbp=fb.1.1773321775944.194409121592664501; _tt_enable_cookie=1; _ttp=01KKH3DVEXF5SVVQSDCXH1YBA1_.tt.1; nps3=SessionStartTime=1773321775,SurveyId=67,ClosedOrCompleted=True; ai_session=DGd+S|1773321720194|1773321877846.2; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%22iMeTzIyzfutKXRbKkQtD%22%2C%22expiryDate%22%3A%222027-03-12T13%3A24%3A38.231Z%22%7D; __rtbh.aid=%7B%22eventType%22%3A%22aid%22%2C%22id%22%3A%227308ed49-1e16-11f1-8bd0-36b44b77cf78%22%2C%22expiryDate%22%3A%222027-03-12T13%3A24%3A38.235Z%22%7D; __rtbh.uid=%7B%22eventType%22%3A%22uid%22%2C%22id%22%3A%22unknown%22%2C%22expiryDate%22%3A%222027-03-12T13%3A24%3A38.239Z%22%7D; ttcsid_CNK74OBC77U1PP7E4UR0=1773321776608::uf27T4wMDb1c092O2OLi.1.1773321878320.1; ttcsid=1773321776608::ep9VqFXPcKADFFNcwFxw.1.1773321878321.0::1.100265.101713::0.0.0.0::0.0.0; ga4_ga_K2N2M0CBQ6=GS2.2.s1773321719$o1$g1$t1773321905$j39$l0$h1980741249",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36",
    "host": "www.ceneo.pl"
}

# %%
url = "https://www.ceneo.pl/7690465#tab=reviews"
response= requests.get(url)
print(response.status_code)

# %% [markdown]
# ### Parsowanie strony z opiniami o produkcie

# %%
page_dom = BeautifulSoup(response.text, "html.parser")
print(page_dom)

# %%
opinions = page_dom.select("div", class_="js_product-review:not(.user-post--highlight)")
print(len(opinions))
print(type(opinions))

# %%
opinion = page_dom.select_one("div", class_="js_product-review:not(.user-post--highlight)") #zwraca pierwsze z brzegu
print(type(opinion))

# %%
opinion = opinions.pop(0)
print(type(opinion))
print(opinion)

# %% [markdown]
# ### Analiza struktury pojedynczej opinii

# %% [markdown]
# |składowa|nazwa|selektor|
# |--------|-----|--------|
# |opinia|opinion|div.js_product-review:not(.user-post--highlight)|
# |identyfikator|opinion_id|[data-entry-id]|
# |autor|author|span.user-post__author-name|
# |treść|content|div.user-post__text|
# |ocena|score|span.user-post__score-count|
# |rekomendacja|recommendation|span.user-post__author-recomendation > em|
# |lista zalet|pros|div.review-feature__item--positive|
# |lista wad|cons|div.review-feature__item--negative|
# |dla ilu przydatna|useful|button.vote-yes > span|
# |dla ilu nieprzydatna|unuseful|button.vote-no > span|
# |data zamieszczenia|publish_date|span.user-post__published > time:nth-child(1)[datetime]|
# |data zakupu|purchase_date|span.user-post__published > time:nth-child(2)[datetime]|
